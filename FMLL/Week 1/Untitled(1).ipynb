# %%
import pandas as pd
import matplotlib as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
#1) Load the mtcars dataset into a Pandas DataFrame and display:
#•	First five records
#•	Last five records
#•	Dataset dimensions (shape)
#•	Column names

data = pd.read_csv("mtcars.csv")
data.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
data.tail()
# Out:
#              model   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %%
data.shape
# Out:
# (32, 12)

# %%
data.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
print(data.columns)
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
data.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
data.isnull().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
X = data["hp"]
y = data["mpg"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=10
)

# %%
def myFnLinReg(x, y):

    x = np.array(x)
    y = np.array(y)

    mean_x = np.mean(x)
    mean_y = np.mean(y)

    slope = np.sum((x - mean_x) * (y - mean_y)) / np.sum((x - mean_x) ** 2)

    intercept = mean_y - slope * mean_x

    return intercept, slope

# %%
intercept, slope = myFnLinReg(X_train, y_train)

print("Slope =", slope)
print("Intercept =", intercept)

print(f"Regression Equation:")
print(f"MPG = {intercept:.3f} + ({slope:.3f} × HP)")
# Out:
# Slope = -0.07622703848957749
# Intercept = 31.88053461802646
# Regression Equation:
# MPG = 31.881 + (-0.076 × HP)

# %%
def predict(x):
    return intercept + slope * np.array(x)

# %%
y_pred = predict(X_test)

print(y_pred)
# Out:
# [24.48651188 27.15445823 23.87669558 24.79142004 23.49556038 20.44647884
#  18.15966769 11.75659646]

# %%
import matplotlib.pyplot as plt

# %%
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plt.figure(figsize=(8,5))

# %%
plt.figure(figsize=(8,5))

plt.scatter(X, y, color="blue")

x_line = np.linspace(X.min(), X.max(),100)

y_line = predict(x_line)

plt.plot(x_line, y_line, color="red")

plt.title("Simple Linear Regression")

plt.xlabel("Horsepower")

plt.ylabel("MPG")

plt.show()

# %%
hp = 150

prediction = predict(hp)

print("Predicted MPG =", prediction)
# Out:
# Predicted MPG = 20.446478844589837

# %%
mse = mean_squared_error(y_test, y_pred)

rmse = np.sqrt(mse)

r2 = r2_score(y_test, y_pred)

print("MSE =", mse)
print("RMSE =", rmse)
print("R2 Score =", r2)
# Out:
# MSE = 13.476253784108575
# RMSE = 3.6710017412293032
# R2 Score = -0.16628611132094084

# %%
data = pd.read_csv("Boston.csv")

# %%
data.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
data.tail()
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm   age     dis  rad  \
# 501         502  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9

# %%
data.shape
# Out:
# (506, 15)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# crim          float64
# zn            float64
# indus         float64
# chas            int64
# nox           float64
# rm            float64
# age           float64
# dis           float64
# rad             int64
# tax             int64
# ptratio       float64
# black         float64
# lstat         float64
# medv          float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# crim          0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# age           0
# dis           0
# rad           0
# tax           0
# ptratio       0
# black         0
# lstat         0
# medv          0
# dtype: int64

# %%
data.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
corr = data.corr()

corr
# Out:
#             Unnamed: 0      crim        zn     indus      chas       nox  \
# Unnamed: 0    1.000000  0.407407 -0.103393  0.399439 -0.003759  0.398736
# crim          0.407407  1.000000 -0.200469  0.406583 -0.055892  0.420972
# zn           -0.103393 -0.200469  1.000000 -0.533828 -0.042697 -0.516604
# indus         0.399439  0.406583 -0.533828  1.000000  0.062938  0.763651
# chas         -0.003759 -0.055892 -0.042697  0.062938  1.000000  0.091203
# nox           0.398736  0.420972 -0.516604  0.763651  0.091203  1.000000
# rm           -0.079971 -0.219247  0.311991 -0.391676  0.091251 -0.302188
# age           0.203784  0.352734 -0.569537  0.644779  0.086518  0.731470
# dis          -0.302211 -0.379670  0.664408 -0.708027 -0.099176 -0.769230
# rad           0.686002  0.625505 -0.311948  0.595129 -0.007368  0.611441
# tax           0.666626  0.582764 -0.314563  0.720760 -0.035587  0.668023
# ptratio       0.291074  0.289946 -0.391679  0.383248 -0.121515  0.188933
# ...

# %%
import seaborn as sns

plt.figure(figsize=(12,8))

sns.heatmap(corr,
            annot=True,
            cmap="coolwarm")

plt.show()

# %%
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
corr["medv"].abs().sort_values(ascending=False)
# Out:
# medv          1.000000
# lstat         0.737663
# rm            0.695360
# ptratio       0.507787
# indus         0.483725
# tax           0.468536
# nox           0.427321
# crim          0.388305
# rad           0.381626
# age           0.376955
# zn            0.360445
# black         0.333461
# dis           0.249929
# Unnamed: 0    0.226604
# chas          0.175260
# Name: medv, dtype: float64

# %%
X = data[["lstat","rm","ptratio"]]

y = data["medv"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
print(len(X_train))
# Out:
# 404

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
comparison = pd.DataFrame({
    "Actual MEDV": y_test,
    "Predicted MEDV": y_pred,
    "Absolute Error": abs(y_test - y_pred)
})

comparison.head()
# Out:
#      Actual MEDV  Predicted MEDV  Absolute Error
# 173         23.6       26.718396        3.118396
# 274         32.4       30.663291        1.736709
# 491         13.6       16.426377        2.826377
# 72          22.8       24.728708        1.928708
# 452         16.1       18.342368        2.242368

# %%
comparison["Absolute Error"].max()
# Out:
# 27.66766072217026

# %%
comparison["Absolute Error"].min()
# Out:
# 0.049974476859542705

# %%
comparison["Absolute Error"].mean()
# Out:
# 3.3325380783240957

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)

mse = mean_squared_error(y_test, y_pred)

rmse = np.sqrt(mse)

r2 = r2_score(y_test, y_pred)

print("MAE =", mae)
print("MSE =", mse)
print("RMSE =", rmse)
print("R2 =", r2)
# Out:
# MAE = 3.332538078324096
# MSE = 27.114957415580577
# RMSE = 5.207202455789536
# R2 = 0.6302528487272827

# %%
plt.scatter(y_test, y_pred)

plt.xlabel("Actual MEDV")

plt.ylabel("Predicted MEDV")

plt.title("Actual vs Predicted")

plt.show()

# %%
residuals = y_test - y_pred

plt.scatter(y_pred, residuals)

plt.axhline(0, color="red")

plt.xlabel("Predicted MEDV")

plt.ylabel("Residuals")

plt.title("Residual Plot")

plt.show()

# %%
new_houses = pd.DataFrame({
    "LSTAT": [5,10,15],
    "RM": [7,6,5],
    "PTRATIO": [15,18,20]
})

pred = model.predict(new_houses)

result = new_houses.copy()

result["Predicted MEDV"] = pred

print(result)
# Out:
#    LSTAT  RM  PTRATIO  Predicted MEDV
# 0      5   7       15       33.277877
# 1     10   6       18       22.907845
# 2     15   5       20       13.404908
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - LSTAT
# - PTRATIO
# - RM
# Feature names seen at fit time, yet now missing:
# - lstat
# - ptratio
# - rm
#
#   warnings.warn(message, FutureWarning)
